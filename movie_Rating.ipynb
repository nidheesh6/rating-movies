# %%
import twitter
import json

# %%
CONSUMER_KEY = 'C4BuijIbFkRfUrDoJRDCPBoik'
CONSUMER_SECRET ='W4RZvPjYRNiEFySipIsEEUIVKBDblqKSYRJJAOIdkfxEbc85ww'
OAUTH_TOKEN = '2826324476-LeV5y9ZVr8ll8Jp33Pb0kyZAzdMHxllfV1mKNkP'
OAUTH_TOKEN_SECRET = 'UtpN7ET6lzpS6fBndHrOqQn6bskmqc0PXtl9vt2YP4etf'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# %%
from urllib.parse import unquote
data={}
q='avengers'
search_results = twitter_api.search.tweets(q=q,lang='en',count=100)
j=len(search_results['statuses'])
print(j)
for i in range(len(search_results['statuses'])):
   data[i]=[search_results['statuses'][i]['text'],search_results['statuses'][i]['retweet_count'],search_results['statuses'][i]['favorite_count']]
search_results
# Out:
# 100
# {'statuses': [{'created_at': 'Sun Nov 03 02:44:32 +0000 2019',
#    'id': 1190822036479848448,
#    'id_str': '1190822036479848448',
#    'text': 'The Kingsman score is a blatant rip off of The Avengers.',
#    'truncated': False,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 921521055629443072,
#     'id_str': '921521055629443072',
#     'name': 'Kai Grósscurth',
#     'screen_name': 'KaiGrosscurth',
#     'location': 'Liverpool, England',
#     'description': 'Aspiring Music Composer at the London College of Music 🎼 🎻 🎹',
#     'url': None,
# ...

# %%
data
# Out:
# {0: ['The Kingsman score is a blatant rip off of The Avengers.', 0, 0],
#  1: ['RT @kisakarly: Looking for new people to chat with! Here’s what I like and am open to suggestions:\nGames\n- The Legend of Zelda\n- Kingdom He…',
#   10,
#   0],
#  2: ["RT @lRNMANS: these are the avengers, the earth's mightest heroes- but we don't have that *hits whiteboard* we have trash in the ocean\n\nhttp…",
#   89187,
#   0],
#  3: ['RT @a_true_blonde: Born to teenage parents.\nGrew up in a South African Township. \nSlept on the floor.\nLost his mother at 15.\nGot a scholars…',
#   436,
#   0],
#  4: ['RT @stellaistired: I only put the 3 avengers. Funny because my family in Mexico are doing the same thing😂😂 https://t.co/XynZjJYVlv',
#   3,
#   0],
#  5: ['RT @magnysus: avengers whenever they see a mutant that just died five hours ago. \nhttps://t.co/VNAMEGyFuR',
#   78,
#   0],
# ...

# %%
with open('avengers.json', 'w') as outfile:
    json.dump(data, outfile)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()
def sentiment_analyzer_scores(sentence):
    score = analyser.polarity_scores(sentence)
    #res = score.partition('compound')[2] 
    #res = dict((k, score[k]) for k in ['compound'] if k in score) 
    #print(str(res))
    #print(score)
    compound = score.get('compound')
    result = ( ( compound + 1 ) / 2 ) * 100
    return result
score1=0
k=0
for i in range(len(search_results['statuses'])):
    score1=score1+sentiment_analyzer_scores(data[i][0])
    k=k+1
k
# Out:
# 100

# %%
score1/k
# Out:
# 51.15909999999999
